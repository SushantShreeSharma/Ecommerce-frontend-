# %% [markdown]
# <a href="https://colab.research.google.com/github/SushantShreeSharma/Ecommerce-frontend-/blob/main/Olympic_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
dataset_path = 'Summer-Olympic-medals-1976-to-2008.csv'

# %%
if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"Dataset not found: {dataset_path}. Please ensure the file is in the correct directory.")

# %%
df = pd.read_csv(dataset_path, encoding='latin1')

# %%
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df.dropna(subset=['Year'], inplace=True)
df['Year'] = df['Year'].astype(int)

# %%
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15316 entries, 0 to 15432
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  int64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 1.4+ MB
# None
#        City  Year     Sport Discipline           Event  \
# 0  Montreal  1976  Aquatics     Diving  3m springboard
# 1  Montreal  1976  Aquatics     Diving  3m springboard
# 2  Montreal  1976  Aquatics     Diving  3m springboard
# ...

# %%
print(df.isnull().sum())

df.fillna("Unknown", inplace=True)
# Out:
# City            0
# Year            0
# Sport           0
# Discipline      0
# Event           0
# Athlete         0
# Gender          0
# Country_Code    0
# Country         0
# Event_gender    0
# Medal           0
# dtype: int64

# %%
country_medals = df['Country'].value_counts().head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=country_medals.index, y=country_medals.values, palette='viridis')
plt.xlabel("Country")
plt.ylabel("Total Medals")
plt.title("Top 10 Countries by Total Olympic Medals")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-20-e50c5a96ea1d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_medals.index, y=country_medals.values, palette='viridis')

# %%
yearly_medals = df.groupby('Year')['Medal'].count()
plt.figure(figsize=(10, 5))
sns.lineplot(x=yearly_medals.index.astype(int), y=yearly_medals.values, marker='o', color='b')
plt.xlabel("Year")
plt.ylabel("Total Medals")
plt.title("Olympic Medals Trend Over the Years")
plt.grid(True)
plt.show()

# %%
medal_counts = df['Medal'].value_counts()
plt.figure(figsize=(7, 5))
sns.barplot(x=medal_counts.index, y=medal_counts.values, palette=['gold', 'silver', 'brown'])
plt.xlabel("Medal Type")
plt.ylabel("Count")
plt.title("Distribution of Medals")
plt.show()

print("Data Analysis Completed!")
# Out:
# <ipython-input-22-47c96c79dc1a>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=medal_counts.index, y=medal_counts.values, palette=['gold', 'silver', 'brown'])
# Data Analysis Completed!
